# %% [markdown]
# # DateTimes

# %% [markdown]
# ### Introduction

# %% [markdown]
# Deciding which features should be included and focused on in our linear model is an important skill of any data scientist.  As we saw previously, if we include features which are too collinear, we will improperly measure the coefficients related to our collinear features.  In addition, feature selection and prioritizing features with feature importance will help us to understand which features to devote our attention to in terms of feature engineering and domain understanding.  Finally, limiting the number of features in our model, and identifying the most crucial features in our model will make our models, and their insights more understandable.

# %% [markdown]
# ### Working with AirBnb

# %% [markdown]
# For this lesson, we'll work with [AirBnb listings in Berlin](https://www.kaggle.com/brittabettendorf/berlin-airbnb-data).

# %%
import pandas as pd
df = pd.read_csv('listings_summary.csv.zip')

# %%
df.shape
# Out:
# (22552, 96)

# %% [markdown]
# As we can see, our dataset as 22,500 rows and close to 100 features.  Our goal is to predict the price.

# %%
# df.columns

# %% [markdown]
# Some of these columns include data that we do not know how to handle - mainly textual data and images.  A lot of this data is simply not in the correct format.  Let's take a look.

# %%
pd.set_option('display.max_rows',100)

# %%
df.describe().T
# Out:
#                                   count          mean           std  \
# id                              22552.0  1.571560e+07  8.552069e+06
# scrape_id                       22552.0  2.018111e+13  4.812607e+00
# thumbnail_url                       0.0           NaN           NaN
# medium_url                          0.0           NaN           NaN
# xl_picture_url                      0.0           NaN           NaN
# host_id                         22552.0  5.403355e+07  5.816290e+07
# host_acceptance_rate                0.0           NaN           NaN
# host_listings_count             22526.0  2.330685e+00  1.994782e+01
# host_total_listings_count       22526.0  2.330685e+00  1.994782e+01
# latitude                        22552.0  5.250982e+01  3.082546e-02
# longitude                       22552.0  1.340611e+01  5.796365e-02
# accommodates                    22552.0  2.637460e+00  1.510548e+00
# bathrooms                       22520.0  1.092695e+00  3.298943e-01
# bedrooms                        22534.0  1.161134e+00  6.461559e-01
# beds                            22512.0  1.620558e+00  1.174840e+00
# square_feet                       446.0  4.654013e+02  5.034919e+02
# guests_included                 22552.0  1.332121e+00  8.350343e-01
# minimum_nights                  22552.0  7.157059e+00  4.066507e+01
# maximum_nights                  22552.0  1.030505e+05  9.640519e+06
# availability_30                 22552.0  4.944173e+00  8.677395e+00
# availability_60                 22552.0  1.114664e+01  1.752237e+01
# availability_90                 22552.0  2.001610e+01  2.834914e+01
# availability_365                22552.0  7.985283e+01  1.193682e+02
# number_of_reviews               22552.0  1.784068e+01  3.676962e+01
# review_scores_rating            18163.0  9.441386e+01  7.639644e+00
# review_scores_accuracy          18138.0  9.663965e+00  7.400390e-01
# review_scores_cleanliness       18141.0  9.324955e+00  1.031996e+00
# review_scores_checkin           18120.0  9.713521e+00  7.046199e-01
# review_scores_communication     18134.0  9.730672e+00  6.866140e-01
# review_scores_location          18121.0  9.505491e+00  7.621606e-01
# review_scores_value             18117.0  9.411106e+00  8.414916e-01
# jurisdiction_names                  0.0           NaN           NaN
# calculated_host_listings_count  22552.0  1.918233e+00  3.667257e+00
# reviews_per_month               18638.0  1.135525e+00  1.507082e+00
#
#                                          min           25%           50%  \
# id                              2.015000e+03  8.065954e+06  1.686638e+07
# scrape_id                       2.018111e+13  2.018111e+13  2.018111e+13
# thumbnail_url                            NaN           NaN           NaN
# medium_url                               NaN           NaN           NaN
# xl_picture_url                           NaN           NaN           NaN
# host_id                         2.217000e+03  9.240002e+06  3.126711e+07
# host_acceptance_rate                     NaN           NaN           NaN
# host_listings_count             0.000000e+00  1.000000e+00  1.000000e+00
# host_total_listings_count       0.000000e+00  1.000000e+00  1.000000e+00
# latitude                        5.234580e+01  5.248906e+01  5.250908e+01
# longitude                       1.310356e+01  1.337541e+01  1.341678e+01
# accommodates                    1.000000e+00  2.000000e+00  2.000000e+00
# bathrooms                       0.000000e+00  1.000000e+00  1.000000e+00
# bedrooms                        0.000000e+00  1.000000e+00  1.000000e+00
# beds                            0.000000e+00  1.000000e+00  1.000000e+00
# square_feet                     0.000000e+00  0.000000e+00  4.035000e+02
# guests_included                 1.000000e+00  1.000000e+00  1.000000e+00
# minimum_nights                  1.000000e+00  2.000000e+00  2.000000e+00
# maximum_nights                  1.000000e+00  2.000000e+01  1.124000e+03
# availability_30                 0.000000e+00  0.000000e+00  0.000000e+00
# availability_60                 0.000000e+00  0.000000e+00  0.000000e+00
# availability_90                 0.000000e+00  0.000000e+00  0.000000e+00
# availability_365                0.000000e+00  0.000000e+00  4.000000e+00
# number_of_reviews               0.000000e+00  1.000000e+00  5.000000e+00
# review_scores_rating            2.000000e+01  9.200000e+01  9.700000e+01
# review_scores_accuracy          2.000000e+00  1.000000e+01  1.000000e+01
# review_scores_cleanliness       2.000000e+00  9.000000e+00  1.000000e+01
# review_scores_checkin           2.000000e+00  1.000000e+01  1.000000e+01
# review_scores_communication     2.000000e+00  1.000000e+01  1.000000e+01
# review_scores_location          2.000000e+00  9.000000e+00  1.000000e+01
# review_scores_value             2.000000e+00  9.000000e+00  1.000000e+01
# jurisdiction_names                       NaN           NaN           NaN
# calculated_host_listings_count  1.000000e+00  1.000000e+00  1.000000e+00
# reviews_per_month               1.000000e-02  1.800000e-01  5.400000e-01
#
#                                          75%           max
# id                              2.258393e+07  2.986735e+07
# scrape_id                       2.018111e+13  2.018111e+13
# thumbnail_url                            NaN           NaN
# medium_url                               NaN           NaN
# xl_picture_url                           NaN           NaN
# host_id                         8.067518e+07  2.245081e+08
# host_acceptance_rate                     NaN           NaN
# host_listings_count             2.000000e+00  1.676000e+03
# host_total_listings_count       2.000000e+00  1.676000e+03
# latitude                        5.253267e+01  5.265167e+01
# longitude                       1.343926e+01  1.375764e+01
# accommodates                    3.000000e+00  1.600000e+01
# bathrooms                       1.000000e+00  8.500000e+00
# bedrooms                        1.000000e+00  1.200000e+01
# beds                            2.000000e+00  2.200000e+01
# square_feet                     7.075000e+02  4.639000e+03
# guests_included                 1.000000e+00  1.600000e+01
# minimum_nights                  4.000000e+00  5.000000e+03
# maximum_nights                  1.125000e+03  1.000000e+09
# availability_30                 6.000000e+00  3.000000e+01
# availability_60                 1.800000e+01  6.000000e+01
# availability_90                 3.600000e+01  9.000000e+01
# availability_365                1.290000e+02  3.650000e+02
# number_of_reviews               1.600000e+01  4.980000e+02
# review_scores_rating            1.000000e+02  1.000000e+02
# review_scores_accuracy          1.000000e+01  1.000000e+01
# review_scores_cleanliness       1.000000e+01  1.000000e+01
# review_scores_checkin           1.000000e+01  1.000000e+01
# review_scores_communication     1.000000e+01  1.000000e+01
# review_scores_location          1.000000e+01  1.000000e+01
# review_scores_value             1.000000e+01  1.000000e+01
# jurisdiction_names                       NaN           NaN
# calculated_host_listings_count  1.000000e+00  4.500000e+01
# reviews_per_month               1.500000e+00  3.667000e+01

# %% [markdown]
# A lot of the data is listed as objects, which is really a catch all.

# %%
df.dtypes[10:15]
# Out:
# notes          object
# transit        object
# access         object
# interaction    object
# house_rules    object
# dtype: object

# %%
def find_object_features(df):
    return list(df.dtypes[df.dtypes == 'object'].index)

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f4b57fdaa545> in <module>
# ----> 1 df.dtypes[df.dtypes == 'object']
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Feature engineering

# %% [markdown]
# Let's try to capture as much of this object data as possible.  In this lesson, we'll start with date values.

# %%
def find_object_feature_values(df):
    object_features = find_object_features(df)
    return df[object_features][:2].values

# %%
find_object_feature_values(df)[0, :3]
# Out:
# array(['https://www.airbnb.com/rooms/2015', '2018-11-07',
#        'Berlin-Mitte Value! Quiet courtyard/very central'], dtype=object)

# %% [markdown]
# We can see that the second column, `last_scraped` should be a date, but is listed as an object.  It would be nice if we could use the `to_datetime` method to put our columns in the correct format.

# %%
pd.to_datetime(df, infer_datetime_format=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-a01bf3a843ac> in <module>
# ----> 1 pd.to_datetime(df, infer_datetime_format=True)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     593             result = Series(values, index=arg.index, name=arg.name)
#     594     elif isinstance(arg, (ABCDataFrame, compat.MutableMapping)):
# --> 595         result = _assemble_from_unit_mappings(arg, errors, box, tz)
#     596     elif isinstance(arg, ABCIndexClass):
#     597         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _assemble_from_unit_mappings(arg, errors, box, tz)
#     687         raise ValueError("to assemble mappings requires at least that "
#     688                          "[year, month, day] be specified: [{required}] "
# --> 689                          "is missing".format(required=','.join(req)))
#     690
#     691     # keys we don't recognize
#
# ValueError: to assemble mappings requires at least that [year, month, day] be specified: [day,month,year] is missing

# %% [markdown]
# But it doesn't work as well as we would hope. Let's write a method called `is_date` that detects if our column value is a date.

# %%
def contains_date(column):
#     remove nas first, potentially use all
    regex_string = (r'^\d{1,2}-\d{1,2}-\d{4}$|^\d{4}-\d{1,2}-\d{1,2}$' + 
'|^\d{1,2}\/\d{1,2}\/\d{4}$|^\d{4}\/\d{1,2}\/\d{1,2}$')
    return column.str.contains(regex_string).any()

# %% [markdown]
# The regex above is wild but it's easier to understand once we understand that each `|` means `or`.  So really, we can think of the above regex as multiple different ones.  So the first one of them is:
#
# `^\d{1,2}-\d{1,2}-\d{4}$`

# %% [markdown]
# Which means start with one or two digits, then one or two digits again, and then four digits.  With each set of digits separated by a hyphen.
#
# `11-22-2018`

# %% [markdown]
# So contains date tells us if any column in the above contains a date.

# %%
def find_date_features(df):
    series_contains_date = df.apply(contains_date)
    return series_contains_date.index[series_contains_date.values]

# %%
date_features = find_date_features(df)

# %%
date_features
# Out:
# Index(['last_scraped', 'host_since', 'calendar_last_scraped', 'first_review',
#        'last_review'],
#       dtype='object')

# %% [markdown]
# Now we can set those features to be date time.

# %%
def to_dates(df):
    date_features = find_date_features(df)
    return df[date_features].astype('datetime64[ns]')

# %%
df_date_features = to_dates(df)

# %%
df_date_features.dtypes

# last_scraped             datetime64[ns]
# host_since               datetime64[ns]
# calendar_last_scraped    datetime64[ns]
# first_review             datetime64[ns]
# last_review              datetime64[ns]

df_date_features[:1]
# Out:
#   last_scraped host_since calendar_last_scraped first_review last_review
# 0   2018-11-07 2008-08-18            2018-11-07   2016-04-11  2018-10-28

# %%
# make it work
# make it right
# make it fast

# %%
from date_lib import add_datepart

# %%
copied_df = df.copy()
add_datepart(copied_df, 'last_scraped')

# %%
# 1. periodic data
# 2. external data
#     * weather
# 3. differences within a row or differences between rows

# %%
copied_df
# Out:
#              id                            listing_url       scrape_id  \
# 0          2015      https://www.airbnb.com/rooms/2015  20181107122246
# 1          2695      https://www.airbnb.com/rooms/2695  20181107122246
# 2          3176      https://www.airbnb.com/rooms/3176  20181107122246
# 3          3309      https://www.airbnb.com/rooms/3309  20181107122246
# 4          7071      https://www.airbnb.com/rooms/7071  20181107122246
# 5          9991      https://www.airbnb.com/rooms/9991  20181107122246
# 6         14325     https://www.airbnb.com/rooms/14325  20181107122246
# 7         16401     https://www.airbnb.com/rooms/16401  20181107122246
# 8         16644     https://www.airbnb.com/rooms/16644  20181107122246
# 9         17409     https://www.airbnb.com/rooms/17409  20181107122246
# 10        17904     https://www.airbnb.com/rooms/17904  20181107122246
# 11        20858     https://www.airbnb.com/rooms/20858  20181107122246
# 12        21869     https://www.airbnb.com/rooms/21869  20181107122246
# 13        22415     https://www.airbnb.com/rooms/22415  20181107122246
# 14        22677     https://www.airbnb.com/rooms/22677  20181107122246
# 15        23834     https://www.airbnb.com/rooms/23834  20181107122246
# 16        24569     https://www.airbnb.com/rooms/24569  20181107122246
# 17        25653     https://www.airbnb.com/rooms/25653  20181107122246
# 18        26543     https://www.airbnb.com/rooms/26543  20181107122246
# 19        28156     https://www.airbnb.com/rooms/28156  20181107122246
# 20        28268     https://www.airbnb.com/rooms/28268  20181107122246
# 21        28711     https://www.airbnb.com/rooms/28711  20181107122246
# 22        29279     https://www.airbnb.com/rooms/29279  20181107122246
# 23        30295     https://www.airbnb.com/rooms/30295  20181107122246
# 24        31440     https://www.airbnb.com/rooms/31440  20181107122246
# 25        33043     https://www.airbnb.com/rooms/33043  20181107122246
# 15     News: Minimum stay: 60 nights The apartment ha...
# 16     The apartment has 150 sqm and is on the 4th fl...
# 17     The apartment has 150 sqm and is on the 4th fl...
# 18     Newly renovated apartment with 2 bathrooms and...
# 19     The apartment is located on the south-facing u...
# 20     Attention, before you send me a booking reques...
# 21     Newly renovated, quiet 1-room apartment (appro...
# 22     The apartment, is on the 2th floor (without el...
# 23     Situated in the heart of popular Prenzlauer Be...
# 24     Large Room , with hardwoodfloor, high ceiling ...
# 25     New fantastic 4G unlimited WIFI included in th...
# 26     Dear Guests - Welcome to Berlin! very nice and...
# 27     I have a furnished room with a single bed in C...
# 28     You get up by stairs, second floor (no elevato...
# 29     Hi!  The apartment is located in the Mitte Pre...
# ...                                                  ...
# 22522  There are many famous shops and a garden near ...
# 22523                                                NaN
# 22524  Dear Berlin Visitors !  I rent a bedroom in a ...
# 22525                                                NaN
# 22526                                                NaN
# 22527                                                NaN
# 22528                                                NaN
# 22529                                                NaN
# 22530                                                NaN
# 22531                                                NaN
# 22532  The building is surrounded by other buildings ...
# 22533                                                NaN
# 22534  Die gesamte Wohnung ist mit ökologisch behande...
# 22535  Die gesamte Wohnung ist mit ökologisch behande...
# 22536                                                NaN
# 22537  Die gesamte Wohnung ist mit ökologisch behande...
# 22538                                                NaN
# 22539                                                NaN
# 22540                                                NaN
# 22541  You can use the kitchen, the bathroom and the ...
# 22542                                                NaN
# 22543                                                NaN
# 22544                                                NaN
# 22545                                                NaN
# 22546  Die Wohnung besteht aus 3,5 Zimmern. 1 sehr gr...
# 22547                                                NaN
# 22548  Die Übernachtungsmöglichkeit ist offen im Wohn...
# 22549                                                NaN
# 22550  Nearby you will find the Brandenburg Gate, Rei...
# 22551                                                NaN
#
#                                              description experiences_offered  \
# 0      Great location!  30 of 75 sq meters. This wood...                none
# 1      In the summertime we are spending most of our ...                none
# 2      This beautiful first floor apartment  is situa...                none
# 3      First of all: I prefer short-notice bookings. ...                none
# 4      Cozy and large room in the beautiful district ...                none
# 5      4 bedroom with very large windows and outstand...                none
# 6      The apartment is located on the upper second f...                none
# 7      Hello future guests! We want to rent our cute ...                none
# 8      Light and sunny 2-Room-turn of the century-fla...                none
# 9      The 25 sqm room is located in the heart of Ber...                none
# 10     - beautiful studio apt in downtown Berlin - br...                none
# 11     Bright and sunny condo with two balconies in a...                none
# 12     Light and sunny 1-Room-turn of the century-fla...                none
# 13     Very nice furnished 2 bedroom apartment for su...                none
# 14     Comfortable, cozy and quiet 70m2 apartment plu...                none
# 15     Beautiful and calm apartment in close vicinity...                none
# 16     The apartment has 150 sqm and is on the 4th fl...                none
# 17     The apartment has 150 sqm and is on the 4th fl...                none
# 18     This flat has permission to rent under Licence...                none
# 19     The apartment is located on the upper ground f...                none
# 20     Attention, before you send me a booking reques...                none
# 21     Newly renovated, quiet 1-room apartment (appro...                none
# 22     This charming apartment located in a building ...                none
# 23     Right in the heart of Prenzlauer Berg, probabl...                none
# 25                                                   NaN
# 26                                                   NaN
# 27     Charlottenburg is tree-lined, with electirc an...
# 28     Although very central the area is quite tradit...
# 29     Once on the fringe of East Berlin, the Prenzla...
# ...                                                  ...
# 22522  Wilmersdorf U9 Günztlerstrasse U7 Berlinerstrasse
# 22523  The constant change of Berlin feels and can be...
# 22524                                                NaN
# 22525                                                NaN
# 22526                                                NaN
# 22527                                                NaN
# 22528                                                NaN
# 22529                                                NaN
# 22530  There's a supermarket on the same block, and t...
# 22531                                                NaN
# 22532                                                NaN
# 22533                                                NaN
# 22534  Diese originale Bauhaus Wohnung bietet Ihnen e...
# 22535  Diese originale Bauhaus Wohnung bietet Ihnen e...
# 22536                                                NaN
# 22537  Diese originale Bauhaus Wohnung bietet Ihnen e...
# 22538                                                NaN
# 22539                                                NaN
# 22540                                                NaN
# 22541  It’s the outskirts of Neukölln between cheap b...
# 22542                                                NaN
# 22543                                                NaN
# 22544                                                NaN
# 22545                                                NaN
# 22546  Szenige und gemütliche Cafés und Restaurants, ...
# 22547  The charming, stylish and cosmopolitan Berlin ...
# 22548                                                NaN
# 22549                                                NaN
# 22550  Within walking distance you can reach many pla...
# 22551  Neukölln entzückt mit seiner unnachahmlichen B...
#
#                                                    notes  ... last_scrapedDay  \
# 0      This is my home, not a hotel. I rent out occas...  ...               7
# 1                                                    NaN  ...               7
# 2      We welcome FAMILIES and cater especially for y...  ...               7
# 3      The flat is a strictly non-smoking facility! A...  ...               7
# 4      I hope you enjoy your stay to the fullest! Ple...  ...               7
# 5                                                    NaN  ...               7
# 6                                                    NaN  ...               7
# 7                                                    NaN  ...               7
# 8                                                    NaN  ...               7
# 9                                                    NaN  ...               7
# 10                                                   NaN  ...               7
# 11     Please note: "The City Tax amounts to five per...  ...               7
# 12                                                   NaN  ...               7
# 13     please be aware theat when you check in later ...  ...               7
# 14     CITY TAX:  as of january 2014 every tourist ha...  ...               7
# 15                                                   NaN  ...               7
# 16                                                   NaN  ...               7
# 17                                                   NaN  ...               7
# 18     Should you be checking in quite late in the ev...  ...               7
# 19                                                   NaN  ...               7
# 20     CITY TAX: The price includes bed linen, bath t...  ...               7
# 21                                                   NaN  ...               7
# 22     If you come with the car: the parking in the s...  ...               7
# 23     "Zweckentfremdungsgesetz" Since May 1st,  a ne...  ...               7
# 24                                                   NaN  ...               7
# 25                                                   NaN  ...               7
# 26                                                   NaN  ...               7
# 27     Guests booked for 7 days and more will be char...  ...               7
# 28     Please note that we usually do not accept shor...  ...               7
# 29                                                   NaN  ...               7
# ...                                                  ...  ...             ...
# 22522         There are some bars near to the apartment.  ...               7
# 22523                                                NaN  ...               7
# 22524                                                NaN  ...               7
# 22525                                                NaN  ...               7
# 22526                                                NaN  ...               7
# 22527                                                NaN  ...               7
# 22528                                                NaN  ...               7
# 22529                                                NaN  ...               7
# 22530                                                NaN  ...               7
# 22531                                                NaN  ...               7
# 22532  Mindestens 4 Monaten Mietdauer. Maximum 6 Mona...  ...               7
# 22533                                                NaN  ...               7
# 22534  Die Wohnung ist eine Nichtraucherwohnung. Das ...  ...               7
# 22535  Die Wohnung ist eine Nichtraucherwohnung. Das ...  ...               7
# 22536                                                NaN  ...               7
# 22537  Die Wohnung ist eine Nichtraucherwohnung. Das ...  ...               7
# 22538                                                NaN  ...               7
# 22539                                                NaN  ...               7
# 22540                                                NaN  ...               7
# 22541                                                NaN  ...               7
# 22542                                                NaN  ...               7
# 22543                                                NaN  ...               7
# 22544                                                NaN  ...               7
# 22545                                                NaN  ...               7
# 22546  Wir sind vom 10.12.2018 - 18.01.2018 im Urlaub...  ...               7
# 22547                                                NaN  ...               7
# 22548                                                NaN  ...               7
# 22549                                                NaN  ...               7
# 22550  At the house the S-Bahn and the long-distance ...  ...               7
# 22551                                                NaN  ...               7
#
#       last_scrapedDayofweek last_scrapedDayofyear last_scrapedIs_month_end  \
# 0                         2                   311                    False
# 1                         2                   311                    False
# 2                         2                   311                    False
# 3                         2                   311                    False
# 4                         2                   311                    False
# 5                         2                   311                    False
# 6                         2                   311                    False
# 7                         2                   311                    False
# 8                         2                   311                    False
# 9                         2                   311                    False
# 10                        2                   311                    False
# 11                        2                   311                    False
# 12                        2                   311                    False
# 13                        2                   311                    False
# 14                        2                   311                    False
# 15                        2                   311                    False
# 16                        2                   311                    False
# 17                        2                   311                    False
# 18                        2                   311                    False
# 19                        2                   311                    False
# 20                        2                   311                    False
# 21                        2                   311                    False
# 22                        2                   311                    False
# 23                        2                   311                    False
# 24                        2                   311                    False
# 25                        2                   311                    False
# 26                        2                   311                    False
# 27                        2                   311                    False
# 28                        2                   311                    False
# 29                        2                   311                    False
# ...                     ...                   ...                      ...
# 22522                     2                   311                    False
# 22523                     2                   311                    False
# 22524                     2                   311                    False
# 22525                     2                   311                    False
# 22526                     2                   311                    False
# 22527                     2                   311                    False
# 22528                     2                   311                    False
# 22529                     2                   311                    False
# 22530                     2                   311                    False
# 22531                     2                   311                    False
# 22532                     2                   311                    False
# 22533                     2                   311                    False
# 22534                     2                   311                    False
# 22535                     2                   311                    False
# 22536                     2                   311                    False
# 22537                     2                   311                    False
# 22538                     2                   311                    False
# 22539                     2                   311                    False
# 22540                     2                   311                    False
# 22541                     2                   311                    False
# 22542                     2                   311                    False
# 22543                     2                   311                    False
# 22544                     2                   311                    False
# 22545                     2                   311                    False
# 22546                     2                   311                    False
# 22547                     2                   311                    False
# 22548                     2                   311                    False
# 22549                     2                   311                    False
# 22550                     2                   311                    False
# 22551                     2                   311                    False
#
#        last_scrapedIs_month_start  last_scrapedIs_quarter_end  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# 5                           False                       False
# 6                           False                       False
# 7                           False                       False
# 8                           False                       False
# 9                           False                       False
# 10                          False                       False
# 11                          False                       False
# 12                          False                       False
# 13                          False                       False
# 14                          False                       False
# 15                          False                       False
# 16                          False                       False
# 17                          False                       False
# 18                          False                       False
# 19                          False                       False
# 20                          False                       False
# 21                          False                       False
# 22                          False                       False
# 23                          False                       False
# 24                          False                       False
# 25                          False                       False
# 26                          False                       False
# 27                          False                       False
# 28                          False                       False
# 29                          False                       False
# ...                           ...                         ...
# 22522                       False                       False
# 22523                       False                       False
# 22524                       False                       False
# 22525                       False                       False
# 22526                       False                       False
# 22527                       False                       False
# 22528                       False                       False
# 22529                       False                       False
# 22530                       False                       False
# 22531                       False                       False
# 22532                       False                       False
# 22533                       False                       False
# 22534                       False                       False
# 22535                       False                       False
# 22536                       False                       False
# 22537                       False                       False
# 22538                       False                       False
# 22539                       False                       False
# 22540                       False                       False
# 22541                       False                       False
# 22542                       False                       False
# 22543                       False                       False
# 22544                       False                       False
# 22545                       False                       False
# 22546                       False                       False
# 22547                       False                       False
# 22548                       False                       False
# 22549                       False                       False
# 22550                       False                       False
# 22551                       False                       False
#
#       last_scrapedIs_quarter_start  last_scrapedIs_year_end  \
# 0                            False                    False
# 1                            False                    False
# 2                            False                    False
# 3                            False                    False
# 4                            False                    False
# 5                            False                    False
# 6                            False                    False
# 7                            False                    False
# 8                            False                    False
# 9                            False                    False
# 10                           False                    False
# 11                           False                    False
# 12                           False                    False
# 13                           False                    False
# 14                           False                    False
# 15                           False                    False
# 16                           False                    False
# 17                           False                    False
# 18                           False                    False
# 19                           False                    False
# 20                           False                    False
# 21                           False                    False
# 22                           False                    False
# 23                           False                    False
# 24                           False                    False
# 25                           False                    False
# 26                           False                    False
# 27                           False                    False
# 28                           False                    False
# 29                           False                    False
# ...                            ...                      ...
# 22522                        False                    False
# 22523                        False                    False
# 22524                        False                    False
# 22525                        False                    False
# 22526                        False                    False
# 22527                        False                    False
# 22528                        False                    False
# 22529                        False                    False
# 22530                        False                    False
# 22531                        False                    False
# 22532                        False                    False
# 22533                        False                    False
# 22534                        False                    False
# 22535                        False                    False
# 22536                        False                    False
# 22537                        False                    False
# 22538                        False                    False
# 22539                        False                    False
# 22540                        False                    False
# 22541                        False                    False
# 22542                        False                    False
# 22543                        False                    False
# 22544                        False                    False
# 22545                        False                    False
# 22546                        False                    False
# 22547                        False                    False
# 22548                        False                    False
# 22549                        False                    False
# 22550                        False                    False
# 22551                        False                    False
#
#        last_scrapedIs_year_start last_scrapedElapsed
# 0                          False          1541548800
# 1                          False          1541548800
# 2                          False          1541548800
# 3                          False          1541548800
# 4                          False          1541548800
# 5                          False          1541548800
# 6                          False          1541548800
# 7                          False          1541548800
# 8                          False          1541548800
# 9                          False          1541548800
# 10                         False          1541548800
# 11                         False          1541548800
# 12                         False          1541548800
# 13                         False          1541548800
# 14                         False          1541548800
# 15                         False          1541548800
# 16                         False          1541548800
# 17                         False          1541548800
# 18                         False          1541548800
# 19                         False          1541548800
# 20                         False          1541548800
# 21                         False          1541548800
# 22                         False          1541548800
# 23                         False          1541548800
# 24                         False          1541548800
# 25                         False          1541548800
# 26                         False          1541548800
# 27                         False          1541548800
# 28                         False          1541548800
# 29                         False          1541548800
# ...                          ...                 ...
# 22522                      False          1541548800
# 22523                      False          1541548800
# 22524                      False          1541548800
# 22525                      False          1541548800
# 22526                      False          1541548800
# 22527                      False          1541548800
# 22528                      False          1541548800
# 22529                      False          1541548800
# 22530                      False          1541548800
# 22531                      False          1541548800
# 22532                      False          1541548800
# 22533                      False          1541548800
# 22534                      False          1541548800
# 22535                      False          1541548800
# 22536                      False          1541548800
# 22537                      False          1541548800
# 22538                      False          1541548800
# 22539                      False          1541548800
# 22540                      False          1541548800
# 22541                      False          1541548800
# 22542                      False          1541548800
# 22543                      False          1541548800
# 22544                      False          1541548800
# 22545                      False          1541548800
# 22546                      False          1541548800
# 22547                      False          1541548800
# 22548                      False          1541548800
# 22549                      False          1541548800
# 22550                      False          1541548800
# 22551                      False          1541548800
#
# [22552 rows x 108 columns]

# %%
def generate_new_date_columns(dates_df):
    copied_dates_df = dates_df.copy()
    for col in copied_dates_df.columns:
        add_datepart(copied_dates_df, col)
    return copied_dates_df

# %%
new_date_col_df = generate_new_date_columns(df_date_features)

# %%
len(new_date_col_df.columns)
# Out:
# 65

# %% [markdown]
# Once coercing our dates, we can merge with the original dataframe, and replace each of the old columns that should be dates.

# %%
def merge_dfs(original_df, new_df):
    copied_original = original_df.copy()
    date_features = find_date_features(original_df)
    copied_dropped = copied_original.drop(columns = date_features)
    copied_dropped[new_df.columns] = new_df
    return copied_dropped

# %%
new_df = merge_dfs(df, new_date_col_df)

# %% [markdown]
# We can confirm that the `new_df` has fewer `object_feature` columns than the original.

# %%
# new_df = new_df.drop(columns = remaining_date_features)
len(find_object_features(new_df))
# Out:
# 57

# %%
len(find_object_features(df))
# Out:
# 62

# %% [markdown]
# Even though our `new_df` has more features.

# %%
len(new_df.columns)
# Out:
# 156

# %% [markdown]
# ### Working with Trickier Dates

# %% [markdown]
# Sometimes we'll have have some features that represents a date, but is worded as text.  For example, the text '6 years ago' could be translated into a date.  Let's write a function that finds this features with this text.  And also write functions to coerce this data into the proper format.

# %%
def contains_time_ago(column):
    regex_string = (r'^\d.*ago$')
    return column.str.contains(regex_string).any()

# %%
def find_time_ago_features(df):
    series_contains_time_ago = df.apply(contains_time_ago)
    return series_contains_time_ago.index[series_contains_time_ago.values]

# %%
find_time_ago_features(df)
# Out:
# Index(['calendar_updated'], dtype='object')

# %%
from date_lib import get_past_date

# %%
calendar_updated = df.calendar_updated.apply(get_past_date).astype('datetime64[ns]')

# %%
calendar_updated[0:3]
# Out:
# 0   2019-04-09
# 1   2019-05-21
# 2   2019-07-02
# Name: calendar_updated, dtype: datetime64[ns]

# %% [markdown]
# Now we can replace our `calendar_updated` column.

# %% [markdown]
# ### Generating New Features

# %% [markdown]
# There are some additional features that we did not generate.  For example, subtracting date columns from another and also subtracting dates from additional key dates like holidays.  Finally, to be even more ambitious, we could match dates to past temperatures if we believe this would help our dataset.

# %% [markdown]
# ### Summary
