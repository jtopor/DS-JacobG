# %% [markdown]
# ### Introduction
#
# Let's continue to use the Texas Mixed Beverage API.  The documentation can be found [here](https://dev.socrata.com/foundry/data.texas.gov/naix-2893) and [here](https://dev.socrata.com/docs/queries/).

# %% [markdown]
# ### Complete the following tasks.

# %% [markdown]
# 1. Find all of the restaurants listed with a zip code of `75002`.

# %%
results = None

# %%
len(results)
# 1000
# Out:
# 1000

# %% [markdown]
# Now display only those results who had total receipts of 0.

# %%
results_with_zero = None

# %%
len(results_with_zero)
# 98

# %% [markdown]
# Next let's try to find the top five results in that zip code with the highest total_receipts.

# %% [markdown]
# > Hint: Think about how this is done in SQL.

# %%
results_of_highest = None

# %%
list(map(lambda result: result['total_receipts'],results_of_highest))
# ['403845', '359448', '344838', '341086', '333538']
# Out:
# ['403845', '359448', '344838', '341086', '333538']

# %% [markdown]
# ### Summary

# %% [markdown]
# Great job.  Continue to search through this API, and see the different queries that you can make.  Note that this is how many governmental APIs work.
